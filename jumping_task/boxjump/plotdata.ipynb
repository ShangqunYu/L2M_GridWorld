# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook
plt.style.use("ggplot")

# %%
lst = [1, 2, 3, 4]
N = 2
moving_average = []

def moving_average(lst, window):
    rolling_average = []
    for i in range(len(lst)):
        if i >= window-1:
            rolling_average.append(sum(lst[i-window+1:i])/window)
    return rolling_average

# %%
l = [1,2,3,4,5]

sum([num > 3 for num in l])
# Out:
# 2

# %%
total_reward_hist = np.load("./results/q_learning_rewards.npy")

# %%
plt.figure()
plt.plot(total_reward_hist, color='blue')

plt.xlabel('Number of Episodes')
plt.ylabel('Total Reward per Episode')
plt.title('Total Reward Using Q-Learning for the Box Jumping Task')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
